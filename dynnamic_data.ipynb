# %% [markdown]
# # Tourist DataSet

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\Downloads\Tourism.csv")

# %%
df.head()
# Out:
#    Route_ID  User_ID                   Sequence  Total_Duration  Total_Cost  \
# 0         1       23      42->32->48->20->29->9             466        1541
# 1         2      124          7->44->43->50->30             151        3817
# 2         3      135   27->3->32->28->2->36->31             559        8087
# 3         4       86  38->2->20->19->40->39->29             159        2218
# 4         5      137                  27->24->3             466        1388
#
#   Weather Traffic_Level Crowd_Density Event_Impact   Optimal_Route_Preference  \
# 0   Sunny        Medium           Low     Festival      9->20->29->32->42->48
# 1   Rainy          High          High     Festival          7->30->43->44->50
# 2   Rainy           Low          High          NaN   2->3->27->28->31->32->36
# 3   Snowy        Medium          High     Festival  2->19->20->29->38->39->40
# 4   Snowy           Low        Medium      Holiday                  3->24->27
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345 entries, 0 to 1344
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Route_ID                  1345 non-null   int64
#  1   User_ID                   1345 non-null   int64
#  2   Sequence                  1345 non-null   object
#  3   Total_Duration            1345 non-null   int64
#  4   Total_Cost                1345 non-null   int64
#  5   Weather                   1345 non-null   object
#  6   Traffic_Level             1345 non-null   object
#  7   Crowd_Density             1345 non-null   object
#  8   Event_Impact              885 non-null    object
#  9   Optimal_Route_Preference  1345 non-null   object
#  10  Satisfaction_Score        1345 non-null   int64
#  11  Age                       1345 non-null   int64
#  12  Gender                    1345 non-null   object
# ...

# %%
df.shape
# Out:
# (1345, 18)

# %%
df.size
# Out:
# 24210

# %%
df.tail()
# Out:
#       Route_ID  User_ID                   Sequence  Total_Duration  \
# 1340      1341      175  22->17->2->34->39->45->19             505
# 1341      1342        9     27->14->41->30->36->22             286
# 1342      1343      190          31->9->49->17->19             447
# 1343      1344       81          10->18->2->32->20             363
# 1344      1345        2              28->8->43->15             562
#
#       Total_Cost Weather Traffic_Level Crowd_Density Event_Impact  \
# 1340        5698   Snowy          High        Medium     Festival
# 1341        4561  Cloudy           Low          High          NaN
# 1342        8910   Sunny        Medium          High      Holiday
# 1343        3330  Cloudy        Medium           Low     Festival
# 1344        3868   Rainy        Medium        Medium     Festival
#
#        Optimal_Route_Preference  Satisfaction_Score  Age  Gender Nationality  \
# 1340  2->17->19->22->34->39->45                   2   46  Female          UK
# ...

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    Route_ID  User_ID                    Sequence  Total_Duration  Total_Cost  \
# 0         1       23       42->32->48->20->29->9             466        1541
# 1         2      124           7->44->43->50->30             151        3817
# 3         4       86   38->2->20->19->40->39->29             159        2218
# 4         5      137                   27->24->3             466        1388
# 5         6      153  29->23->40->16->49->37->14             556        5212
#
#   Weather Traffic_Level Crowd_Density Event_Impact  \
# 0   Sunny        Medium           Low     Festival
# 1   Rainy          High          High     Festival
# 3   Snowy        Medium          High     Festival
# 4   Snowy           Low        Medium      Holiday
# 5   Sunny           Low          High     Festival
#
#      Optimal_Route_Preference  Satisfaction_Score  Age  Gender Nationality  \
# 0       9->20->29->32->42->48                   2   61   Other         USA
# ...

# %%
print("Remove row with missing values so remaning data :",df.shape)
# Out:
# Remove row with missing values so remaning data : (885, 18)

# %%
df = df.drop('Route_ID', axis=1)

# %%
df.shape
# Out:
# (885, 17)

# %%
df.isnull().sum()
# Out:
# Route_ID                    0
# User_ID                     0
# Sequence                    0
# Total_Duration              0
# Total_Cost                  0
# Weather                     0
# Traffic_Level               0
# Crowd_Density               0
# Event_Impact                0
# Optimal_Route_Preference    0
# Satisfaction_Score          0
# Age                         0
# Gender                      0
# Nationality                 0
# Travel_Companions           0
# Budget_Category             0
# Preferred_Theme             0
# Preferred_Transport         0
# dtype: int64

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Cleaning a data

# %%
df.to_csv("cleaned_dataset.csv", index=False)
